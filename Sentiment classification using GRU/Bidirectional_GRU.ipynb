# %%
import tensorflow as tf

# %%
import tensorflow_datasets as tfds
imdb, info = tfds.load("imdb_reviews", with_info=True, as_supervised=True)
# Out:
# Downloading and preparing dataset imdb_reviews/plain_text/1.0.0 (download: 80.23 MiB, generated: Unknown size, total: 80.23 MiB) to /root/tensorflow_datasets/imdb_reviews/plain_text/1.0.0...
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Dl Completed...', max=1.0, style=Progre…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Dl Size...', max=1.0, style=ProgressSty…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Shuffling and writing examples to /root/tensorflow_datasets/imdb_reviews/plain_text/1.0.0.incompleteLWAIXL/imdb_reviews-train.tfrecord
# HBox(children=(FloatProgress(value=0.0, max=25000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Shuffling and writing examples to /root/tensorflow_datasets/imdb_reviews/plain_text/1.0.0.incompleteLWAIXL/imdb_reviews-test.tfrecord
# HBox(children=(FloatProgress(value=0.0, max=25000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Shuffling and writing examples to /root/tensorflow_datasets/imdb_reviews/plain_text/1.0.0.incompleteLWAIXL/imdb_reviews-unsupervised.tfrecord
# HBox(children=(FloatProgress(value=0.0, max=50000.0), HTML(value='')))
# Dataset imdb_reviews downloaded and prepared to /root/tensorflow_datasets/imdb_reviews/plain_text/1.0.0. Subsequent calls will reuse this data.

# %%
import numpy as np

train_data, test_data = imdb['train'], imdb['test']

training_sentences = []
training_labels = []

testing_sentences = []
testing_labels = []


for s,l in train_data:
  training_sentences.append(str(s.numpy()))
  training_labels.append(l.numpy())
  
for s,l in test_data:
  testing_sentences.append(str(s.numpy()))
  testing_labels.append(l.numpy())
  
training_labels_final = np.array(training_labels)
testing_labels_final = np.array(testing_labels)

# %%
vocab_size = 10000
embedding_dim = 16
max_length = 120
trunc_type='post'
oov_tok = "<OOV>"


from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

tokenizer = Tokenizer(num_words = vocab_size, oov_token=oov_tok)
tokenizer.fit_on_texts(training_sentences)
word_index = tokenizer.word_index
sequences = tokenizer.texts_to_sequences(training_sentences)
padded = pad_sequences(sequences,maxlen=max_length, truncating=trunc_type)

testing_sequences = tokenizer.texts_to_sequences(testing_sentences)
testing_padded = pad_sequences(testing_sequences,maxlen=max_length)

# %%
reverse_word_index = dict([(value, key) for (key, value) in word_index.items()])

def decode_review(text):
    return ' '.join([reverse_word_index.get(i, '?') for i in text])

print(decode_review(padded[1]))
print(training_sentences[1])
# Out:
# ? ? ? ? ? ? ? b'i have been known to fall asleep during films but this is usually due to a combination of things including really tired being warm and comfortable on the <OOV> and having just eaten a lot however on this occasion i fell asleep because the film was rubbish the plot development was constant constantly slow and boring things seemed to happen but with no explanation of what was causing them or why i admit i may have missed part of the film but i watched the majority of it and everything just seemed to happen of its own <OOV> without any real concern for anything else i cant recommend this film at all '
# b'I have been known to fall asleep during films, but this is usually due to a combination of things including, really tired, being warm and comfortable on the sette and having just eaten a lot. However on this occasion I fell asleep because the film was rubbish. The plot development was constant. Constantly slow and boring. Things seemed to happen, but with no explanation of what was causing them or why. I admit, I may have missed part of the film, but i watched the majority of it and everything just seemed to happen of its own accord without any real concern for anything else. I cant recommend this film at all.'

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Embedding(vocab_size, embedding_dim, input_length=max_length),
    tf.keras.layers.Bidirectional(tf.keras.layers.GRU(32)),
    tf.keras.layers.Dense(6, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])
model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 120, 16)           160000
# _________________________________________________________________
# bidirectional (Bidirectional (None, 64)                9600
# _________________________________________________________________
# dense (Dense)                (None, 6)                 390
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 7
# =================================================================
# Total params: 169,997
# Trainable params: 169,997
# Non-trainable params: 0
# _________________________________________________________________

# %%
num_epochs = 50
history = model.fit(padded, training_labels_final, epochs=num_epochs, validation_data=(testing_padded, testing_labels_final))
# Out:
# Epoch 1/50
# 782/782 [==============================] - 14s 18ms/step - loss: 0.5263 - accuracy: 0.7102 - val_loss: 0.3510 - val_accuracy: 0.8479
# Epoch 2/50
# 782/782 [==============================] - 14s 17ms/step - loss: 0.2982 - accuracy: 0.8796 - val_loss: 0.3616 - val_accuracy: 0.8454
# Epoch 3/50
# 782/782 [==============================] - 14s 17ms/step - loss: 0.2253 - accuracy: 0.9133 - val_loss: 0.3830 - val_accuracy: 0.8437
# Epoch 4/50
# 782/782 [==============================] - 14s 17ms/step - loss: 0.1659 - accuracy: 0.9381 - val_loss: 0.4541 - val_accuracy: 0.8390
# Epoch 5/50
# 782/782 [==============================] - 13s 17ms/step - loss: 0.1180 - accuracy: 0.9592 - val_loss: 0.5323 - val_accuracy: 0.8316
# Epoch 6/50
# 782/782 [==============================] - 14s 17ms/step - loss: 0.0802 - accuracy: 0.9744 - val_loss: 0.6131 - val_accuracy: 0.8288
# Epoch 7/50
# 782/782 [==============================] - 14s 18ms/step - loss: 0.0571 - accuracy: 0.9813 - val_loss: 0.7168 - val_accuracy: 0.8229
# Epoch 8/50
# 782/782 [==============================] - 15s 19ms/step - loss: 0.0359 - accuracy: 0.9882 - val_loss: 0.8467 - val_accuracy: 0.8219
# Epoch 9/50
# 782/782 [==============================] - 14s 17ms/step - loss: 0.0272 - accuracy: 0.9918 - val_loss: 0.8874 - val_accuracy: 0.8195
# Epoch 10/50
# 782/782 [==============================] - 14s 17ms/step - loss: 0.0268 - accuracy: 0.9912 - val_loss: 0.8649 - val_accuracy: 0.8122
# Epoch 11/50
# 782/782 [==============================] - 14s 18ms/step - loss: 0.0183 - accuracy: 0.9937 - val_loss: 1.0075 - val_accuracy: 0.8135
# Epoch 12/50
# 782/782 [==============================] - 14s 17ms/step - loss: 0.0134 - accuracy: 0.9961 - val_loss: 1.0985 - val_accuracy: 0.8123
# Epoch 13/50
# 782/782 [==============================] - 13s 17ms/step - loss: 0.0085 - accuracy: 0.9975 - val_loss: 1.1315 - val_accuracy: 0.8189
# Epoch 14/50
# 782/782 [==============================] - 14s 17ms/step - loss: 0.0090 - accuracy: 0.9974 - val_loss: 1.2109 - val_accuracy: 0.8151
# Epoch 15/50
# 782/782 [==============================] - 13s 17ms/step - loss: 0.0087 - accuracy: 0.9972 - val_loss: 1.1595 - val_accuracy: 0.8130
# Epoch 16/50
# 782/782 [==============================] - 14s 17ms/step - loss: 0.0096 - accuracy: 0.9969 - val_loss: 1.3885 - val_accuracy: 0.8110
# Epoch 17/50
# 782/782 [==============================] - 14s 17ms/step - loss: 0.0059 - accuracy: 0.9979 - val_loss: 1.3110 - val_accuracy: 0.8141
# Epoch 18/50
# 782/782 [==============================] - 13s 17ms/step - loss: 0.0045 - accuracy: 0.9984 - val_loss: 1.2896 - val_accuracy: 0.8128
# Epoch 19/50
# 782/782 [==============================] - 13s 17ms/step - loss: 0.0071 - accuracy: 0.9977 - val_loss: 1.3723 - val_accuracy: 0.8194
# Epoch 20/50
# 782/782 [==============================] - 13s 17ms/step - loss: 0.0076 - accuracy: 0.9974 - val_loss: 1.3773 - val_accuracy: 0.8146
# Epoch 21/50
# 782/782 [==============================] - 13s 17ms/step - loss: 0.0034 - accuracy: 0.9990 - val_loss: 1.3368 - val_accuracy: 0.8099
# Epoch 22/50
# 782/782 [==============================] - 13s 17ms/step - loss: 0.0072 - accuracy: 0.9974 - val_loss: 1.3566 - val_accuracy: 0.8157
# Epoch 23/50
# 782/782 [==============================] - 13s 17ms/step - loss: 0.0042 - accuracy: 0.9986 - val_loss: 1.3338 - val_accuracy: 0.8100
# Epoch 24/50
# 782/782 [==============================] - 14s 17ms/step - loss: 0.0019 - accuracy: 0.9996 - val_loss: 1.4624 - val_accuracy: 0.8150
# Epoch 25/50
# 782/782 [==============================] - 13s 17ms/step - loss: 0.0064 - accuracy: 0.9977 - val_loss: 1.4102 - val_accuracy: 0.8104
# Epoch 26/50
# 782/782 [==============================] - 14s 17ms/step - loss: 0.0040 - accuracy: 0.9987 - val_loss: 1.4714 - val_accuracy: 0.8184
# Epoch 27/50
# 782/782 [==============================] - 13s 17ms/step - loss: 9.0943e-04 - accuracy: 0.9998 - val_loss: 1.5522 - val_accuracy: 0.8134
# Epoch 28/50
# 782/782 [==============================] - 13s 17ms/step - loss: 7.1586e-05 - accuracy: 1.0000 - val_loss: 1.6388 - val_accuracy: 0.8138
# Epoch 29/50
# 782/782 [==============================] - 13s 17ms/step - loss: 2.6831e-05 - accuracy: 1.0000 - val_loss: 1.6754 - val_accuracy: 0.8136
# Epoch 30/50
# 782/782 [==============================] - 14s 17ms/step - loss: 1.8389e-05 - accuracy: 1.0000 - val_loss: 1.7235 - val_accuracy: 0.8132
# Epoch 31/50
# 782/782 [==============================] - 14s 18ms/step - loss: 1.3043e-05 - accuracy: 1.0000 - val_loss: 1.7759 - val_accuracy: 0.8132
# Epoch 32/50
# 782/782 [==============================] - 13s 17ms/step - loss: 9.1330e-06 - accuracy: 1.0000 - val_loss: 1.8313 - val_accuracy: 0.8136
# Epoch 33/50
# 782/782 [==============================] - 14s 17ms/step - loss: 6.3199e-06 - accuracy: 1.0000 - val_loss: 1.8865 - val_accuracy: 0.8130
# Epoch 34/50
# 782/782 [==============================] - 13s 17ms/step - loss: 4.3273e-06 - accuracy: 1.0000 - val_loss: 1.9496 - val_accuracy: 0.8133
# Epoch 35/50
# 782/782 [==============================] - 13s 17ms/step - loss: 2.9366e-06 - accuracy: 1.0000 - val_loss: 2.0115 - val_accuracy: 0.8134
# Epoch 36/50
# 782/782 [==============================] - 14s 17ms/step - loss: 1.9768e-06 - accuracy: 1.0000 - val_loss: 2.0749 - val_accuracy: 0.8136
# Epoch 37/50
# 782/782 [==============================] - 13s 17ms/step - loss: 1.3237e-06 - accuracy: 1.0000 - val_loss: 2.1398 - val_accuracy: 0.8136
# Epoch 38/50
# 782/782 [==============================] - 14s 17ms/step - loss: 8.8099e-07 - accuracy: 1.0000 - val_loss: 2.2047 - val_accuracy: 0.8139
# Epoch 39/50
# 782/782 [==============================] - 13s 17ms/step - loss: 5.8418e-07 - accuracy: 1.0000 - val_loss: 2.2705 - val_accuracy: 0.8140
# Epoch 40/50
# 782/782 [==============================] - 13s 17ms/step - loss: 3.8702e-07 - accuracy: 1.0000 - val_loss: 2.3364 - val_accuracy: 0.8140
# Epoch 41/50
# 782/782 [==============================] - 14s 17ms/step - loss: 2.5711e-07 - accuracy: 1.0000 - val_loss: 2.4023 - val_accuracy: 0.8138
# Epoch 42/50
# 782/782 [==============================] - 14s 17ms/step - loss: 1.7060e-07 - accuracy: 1.0000 - val_loss: 2.4701 - val_accuracy: 0.8136
# Epoch 43/50
# 782/782 [==============================] - 14s 17ms/step - loss: 1.1329e-07 - accuracy: 1.0000 - val_loss: 2.5369 - val_accuracy: 0.8133
# Epoch 44/50
# 782/782 [==============================] - 13s 17ms/step - loss: 7.5841e-08 - accuracy: 1.0000 - val_loss: 2.5998 - val_accuracy: 0.8133
# Epoch 45/50
# 782/782 [==============================] - 13s 17ms/step - loss: 5.0836e-08 - accuracy: 1.0000 - val_loss: 2.6613 - val_accuracy: 0.8132
# Epoch 46/50
# 782/782 [==============================] - 13s 17ms/step - loss: 3.4370e-08 - accuracy: 1.0000 - val_loss: 2.7253 - val_accuracy: 0.8134
# Epoch 47/50
# 782/782 [==============================] - 13s 17ms/step - loss: 2.3457e-08 - accuracy: 1.0000 - val_loss: 2.7830 - val_accuracy: 0.8136
# Epoch 48/50
# 782/782 [==============================] - 13s 17ms/step - loss: 1.6153e-08 - accuracy: 1.0000 - val_loss: 2.8425 - val_accuracy: 0.8136
# Epoch 49/50
# 782/782 [==============================] - 13s 17ms/step - loss: 1.1278e-08 - accuracy: 1.0000 - val_loss: 2.8973 - val_accuracy: 0.8136
# Epoch 50/50
# 782/782 [==============================] - 13s 17ms/step - loss: 7.9841e-09 - accuracy: 1.0000 - val_loss: 2.9537 - val_accuracy: 0.8135

# %%
import matplotlib.pyplot as plt


def plot_graphs(history, string):
  plt.plot(history.history[string])
  plt.plot(history.history['val_'+string])
  plt.xlabel("Epochs")
  plt.ylabel(string)
  plt.legend([string, 'val_'+string])
  plt.show()

plot_graphs(history, 'accuracy')
plot_graphs(history, 'loss')
